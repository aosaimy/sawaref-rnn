# %%
import pandas as pd

# %%
import sys
sys.executable
# Out:
# '/Users/abbander/dev/py_env/tf1.4py3.5/bin/python'

# %%
import mysql.connector

config = {
    'user' : 'root',
    'passwd' : 'bndr4905',
    'host' : 'localhost',
    'raise_on_warnings' : True,
    'use_pure' : False,
    'database': 'maq_calc_2018'
    }
cnx = mysql.connector.connect(**config)
cursor = cnx.cursor(buffered=True)

# %%
x = '''
تسلسل	رمز الشركة	اسم الشركة المختصر	اسم الشركة	         الرأي          الشرعي	القطاعات حسب تصنيف (GICS)	نسبة الدخل التقليدي	نسبة الاستثمارات التقليدية	نسبة القروض التقليدية	مبلغ التطهير لكل سهم	Legal opinion	Short Name	Company's name	Sectors by Category (GICS)
1	4200	الدريس	شركة الدريس للخدمات البترولية والنقليات	نقية	الطاقة	0.0000000000	0.0000000000	0.0000000000	0.0024197390	Pure	Aldrees	Aldrees Petroleum and Transport Services Co.	Energy
2	1301	أسلاك	شركة اتحاد مصانع الأسلاك	نقية	المواد الأساسية	0.0000000000	0.0000000000	0.0000000000	0.0120050062	Pure	ASLAK	United Wire Factories Co.	Materials
3	2001	كيمانول	شركة كيمائيات الميثانول (كيمانول)	نقية	المواد الأساسية	0.0000000000	0.0000000000	0.0000000000	0.0003749345	Pure	CHEMANOL	Methanol Chemicals Co.	Materials
4	2020	سافكو	شركة الأسمدة العربية السعودية (سافكو)	نقية	المواد الأساسية	0.0000000000	0.0000000000	0.0000000000	0.0086316653	Pure	SAFCO	Saudi Arabia Fertilizers Co.	Materials
5	2090	جبسكو	شركة الجبس الأهلية	نقية	المواد الأساسية	0.0000000000	0.0000000000	0.0000000000	0.0115271098	Pure	NGC	National Gypsum Co.	Materials
6	2150	زجاج	شركة الصناعات الزجاجية الوطنية	نقية	المواد الأساسية	0.0000000000	0.0000000000	0.0000000000	0.0284313641	Pure	Zoujaj	The National Company for Glass Industries	Materials
7	2170	اللجين	شركة اللجين	نقية	المواد الأساسية	0.0000000000	0.0000000000	0.0000000000	0.0416901373	Pure	Alujain	Alujain Corp.	Materials
8	2330	المتقدمة	الشركة المتقدمة للبتروكيماويات	نقية	المواد الأساسية	0.0000000000	0.0000000000	0.0000000000	0.0179368782	Pure	Advanced	Advanced Petrochemical Co.	Materials
9	3002	اسمنت نجران	شركة اسمنت نجران	نقية	المواد الأساسية	0.0000000000	0.0000000000	0.0000000000	0.0002614706	Pure	Najran Cement	Najran Cement Co.	Materials
10	3005	اسمنت أم القرى	شركة اسمنت أم القرى	نقية	المواد الأساسية	0.0000000000	0.0000000000	0.0000000000	0.0018690478	Pure	UACC	Umm Al-Qura Cement Co.	Materials
11	3007	الواحة	شركة زهرة الواحة للتجارة	نقية	المواد الأساسية	0.0000000000	0.0000000000	0.0000000000	0.0031879502	Pure	OASIS 	Zahrat Al Waha for Trading Co.	Materials
12	3030	الإسمنت السعودي	شركة الإسمنت السعودية	نقية	المواد الأساسية	0.0000000000	0.0000000000	0.0000000000	0.0029809804	Pure	SCC	Saudi Cement Co.	Materials
13	3040	اسمنت القصيم	شركة اسمنت القصيم	نقية	المواد الأساسية	0.0000000000	0.0000000000	0.0000000000	0.0133939938	Pure	QACCO	Qassim Cement Co.	Materials
14	3080	اسمنت الشرقية	شركة اسمنت المنطقة الشرقية	نقية	المواد الأساسية	0.0000000000	0.0000000000	0.0000000000	0.0134655523	Pure	EPCCO 	Eastern Province Cement Co.	Materials
15	3090	اسمنت تبوك	شركة اسمنت تبوك	نقية	المواد الأساسية	0.0000000000	0.0000000000	0.0000000000	0.0049091395	Pure	TCC	Tabuk Cement Co.	Materials
16	1303	صناعات كهربائية	شركة الصناعات الكهربائية	نقية	السلع الرأس مالية	0.0000000000	0.0000000000	0.0000000000	0.0041877448	Pure	EIC	Electrical Industries Co.	Capital Goods
133	2160	اميانتيت	شركة أميانتيت العربية السعودية	غير متوافقة	السلع الرأس مالية	0.0004801412	0.0216807292	0.4987995870	0.0159845238	Non-Shariah Complaint	Amiantit	Saudi Arabian Amiantit Co.	Capital Goods
134	4290	الخليج للتدريب	شركة الخليج للتدريب والتعليم	غير متوافقة	الخدمات الإستهلاكية	0.0000000000	0.0000000000	0.3668323226	0.0029435114	Non-Shariah Complaint	Alkhaleej Trng	Alkhaleej Training and Education Co.	Consumer Services
135	1214	شاكر	شركة الحسن غازي إبراهيم شاكر	غير متوافقة	تجزئة السلع الكمالية	0.0000000000	0.0000000000	0.3421435540	0.0249011111	Non-Shariah Complaint	SHAKER	Al Hassan Ghazi Ibrahim Shaker Co.	Retailing
136	4006	أسواق المزرعة	الشركة السعودية للتسويق	غير متوافقة	تجزئة الأغذية	0.0000000000	0.0000000000	0.3385484063	0.0012111056	Non-Shariah Complaint	Farm Superstores	Saudi Marketing Co.	Food & Staples Retailing
137	9500	أبو معطي	شركة عبد الله سعد محمد أبو معطي للمكتبات	غير متوافقة	تجزئة السلع الكمالية (موازي)	0.0000000000	0.0000000000	0.3394384644	0.0077135038	Non-Shariah Complaint	ABO MOATI 	Abdullah Saad Mohammed Abo Moati for Bookstores Co.	Consumer Discretionary
138	4270	طباعة وتغليف	الشركة السعودية للطباعة والتغليف	غير متوافقة النشاط	الخدمات التجارية والمهنية	0.0000000000	0.0134303060	0.4587304729	0.0044582664	Non-Shariah Complaint Activity	SPPC	Saudi Printing and Packaging Co.	Commercial & Professional Svc
139	4011	لازوردي	شركة لازوردي للمجوهرات	غير متوافقة النشاط	السلع طويلة الأجل	0.0000000000	0.0006783836	0.0000000000	0.0026099219	Non-Shariah Complaint Activity	LAZURDE	Lazurde Company for Jewelry	Consumer Durables & Apparel
140	4210	الأبحاث والتسويق	المجموعة السعودية للأبحاث والتسويق	غير متوافقة النشاط	الإعلام	0.0000000000	0.0082512997	0.3380096778	0.0131485645	Non-Shariah Complaint Activity	SRMG	Saudi Research and Marketing Group	Media
141	4280	المملكة	شركة المملكة القابضة	غير متوافقة النشاط	الاستثمار والتمويل	0.0000000000	0.2156828910	0.2793554757	0.0221788769	Non-Shariah Complaint Activity	Kingdom	Kingdom Holding Co.	Diversified Financials
'''

# %%
data = [[y.strip().replace("'","") for y in x.split("\t")] for x in x.split("\n") if x != '']
df = pd.DataFrame(data[1:], columns=data[0])
df
# Out:
#     تسلسل رمز الشركة  اسم الشركة المختصر  \
# 0       1       4200              الدريس
# 1       2       1301               أسلاك
# 2       3       2001             كيمانول
# 3       4       2020               سافكو
# 4       5       2090               جبسكو
# 5       6       2150                زجاج
# 6       7       2170              اللجين
# 7       8       2330            المتقدمة
# 8       9       3002         اسمنت نجران
# 9      10       3005      اسمنت أم القرى
# 10     11       3007              الواحة
# 11     12       3030     الإسمنت السعودي
# 12     13       3040        اسمنت القصيم
# 13     14       3080       اسمنت الشرقية
# 14     15       3090          اسمنت تبوك
# 15     16       1303     صناعات كهربائية
# 16     17       1330              الخضري
# 17     18       4140              صادرات
# 18     19       6004             التموين
# 19     20       4040             الجماعي
# 20     21       4260                بدجت
# 21     22       1213       مجموعة السريع
# ...

# %%
# %%capture cap --no-stderr
print('START TRANSACTION;')

YEAR = 2017

query = ("SELECT sshort_en FROM `sectors`")

cursor.execute(query, ())

prev_sectors = [x[0].decode('utf8') for x in cursor ]

new_sectors = list(set(df["Sectors by Category (GICS)"]))
new_sectors 
not_found = [x for x in new_sectors if x not in prev_sectors]
for nf in not_found:
    row = df.loc[df['Sectors by Category (GICS)']==nf]
    print('INSERT INTO sectors VALUES (null,"NEW","{}","{}");'.format(row.iloc[0]["القطاعات حسب تصنيف (GICS)"], row.iloc[0]["Sectors by Category (GICS)"]))
   
query = ("SELECT ccode FROM `companies`")

cursor.execute(query, ())

prev_companies = [x[0] for x in cursor ]
new_companies = [int(x) for x in list(set(df["رمز الشركة"]))]
not_found = [x for x in new_companies if x not in prev_companies]
# print(prev_companies, new_companies)
# print(not_found)
for nf in not_found:
#     print(nf)
    row = df.loc[df['رمز الشركة']==str(nf)]
    if len(row) == 0:
#         print("ERROR")
        break
    print('''
    INSERT INTO `companies` (`cid`, `cname_ar`, `cshort_ar`, `ccode`, `cname_en`, `cshort_en`, `sid`) 
       VALUES (NULL, '{}', '{}', '{}', '{}', '{}', ({}));
    '''.format(
        row.iloc[0]["اسم الشركة"],
        row.iloc[0]["اسم الشركة المختصر"],
        row.iloc[0]["رمز الشركة"],
        row.iloc[0]["Companys name"],
        row.iloc[0]["Short Name"],
        'SELECT sid FROM sectors WHERE sshort_en = \'' +row.iloc[0]["Sectors by Category (GICS)"]+"'",
        )
    )

for nf in range(len(df)):
    row = df.iloc[nf]
    print('''
    INSERT INTO company_type 
       VALUES (null,({}), ({}), {}); # {}
    '''.format(
        "SELECT cid from companies WHERE ccode = '{}'".format(row["رمز الشركة"]),
        "SELECT tid FROM types WHERE type_ar = '{}'".format(row["الرأي          الشرعي"]),
        YEAR,
        row["اسم الشركة المختصر"],
        )
    )
with open('sqls.sql', 'a') as f:
    f.write(cap.stdout)
cap.stdout

for nf in range(len(df)):
    row = df.iloc[nf]
    print('''
    INSERT INTO pure
       VALUES (null,({}), {}, {}, {}, {}, {}); # {}
    '''.format(
        "SELECT cid from companies WHERE ccode = '{}'".format(row["رمز الشركة"]),
        YEAR,
        float(row["مبلغ التطهير لكل سهم"]),
        float(row["نسبة الدخل التقليدي"].replace("%","")),
        float(row["نسبة الاستثمارات التقليدية"].replace("%","")),
        float(row["نسبة القروض التقليدية"].replace("%","")),
        row["اسم الشركة المختصر"],
        )
    )

with open('sqls.sql', 'a') as f:
    f.write(cap.stdout)


print("ROLLBACK;")
with open('sqls.sql', 'w') as f:
    f.write(cap.stdout)
    f.close()

# %%
cursor.close()
cnx.close()

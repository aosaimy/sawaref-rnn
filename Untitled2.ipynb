# %%
# coding: utf-8

# # 1. Import

'''
    An implementation of sequence to sequence learning
    for performing ensemble morphosyntactic analyses
'''
from __future__ import print_function
# from keras.preprocessing.sequence import pad_sequences
import numpy as np
from six.moves import range
from prepare_data import SawarefData, padIndexes
from character_table import CharacterTable  # , eprint
import pandas as pd
import itertools
import re
import pickle
# import sys
import datetime
from keras.callbacks import TensorBoard
from buckwalter import utf2bw  # , bw2utf
from pprint import pprint
import matplotlib as mpl
mpl.use('Agg')
import matplotlib.pyplot as plt

# do not import in interactive mode
# from vis import SawarefVis
from keras.models import Model, load_model
from keras import layers
from keras.callbacks import EarlyStopping, Callback
from keras.utils import plot_model

from gensim.models import FastText
# Out:
# /Users/abbander/dev/py_env/tf1.4py3.5/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# # 2. Constants

NAME = input("What is the name of this experiment? ")
print("\nNAME=", NAME)
thedate = datetime.datetime.now().strftime(".%Y.%m.%d.%H.%M")
# Out:
# What is the name of this experiment? check_agg_acc
#
# NAME= check_agg_acc

# %%
class TestCallback(Callback):
    def __init__(self, test_data):
        self.test_data = test_data

    def on_epoch_end(self, epoch, logs={}):
        x, y = self.test_data
        metrics = self.model.evaluate(x, y, verbose=0)
        for i, x in enumerate(self.model.metrics_names):
            logs["test_" + x] = metrics[i]
        logs['test_acc'] = np.mean([
            logs["test_" + x] for x in self.model.metrics_names
            if x[-4:] == '_acc'
        ])
        logs['val_acc'] = np.mean([
            logs["val_" + x] for x in self.model.metrics_names
            if x[-4:] == '_acc'
        ])
        logs['train_acc'] = np.mean(
            [logs[x] for x in self.model.metrics_names if x[-4:] == '_acc'])
        return logs


MYPATH = "/morpho/output/"
# Parameters for the model and dataset.
TRAINING_SIZE = 50000
EPOCHS = 100
EMBEDDINGS = 100
# DIGITS = 3
# REVERSE = True
# Try replacing GRU, or SimpleRNN.
HIDDEN_SIZE = 128
BATCH_SIZE = 64
LAYERS = 1
ITERATIONS = 10
REVERSE = False
MODEL_NAME = "main-seq-multiinput-multioutput-segmentation.keras"
DATA_PICKLE = "main-seq-multiinput-multioutput-segmentation.pickle"
RNN = layers.LSTM
CATS_EMBEDDING = 5
VAL_SPLIT = 1  # means 0.1 of data is for test
TEST_SPLIT = 8  # means 0.1 of data is for test

WORD_EMB = False

if WORD_EMB:
    print("Loading FastText model", flush=True)
    emb = FastText.load_fasttext_format(
        "/Users/abbander/Leeds/OpenArabic/data/classical.bin")
    print(" Loaded.")

# %%
# # 3. Config

# `feat_x` is the input categorical features
# `feat_y` is the output categorical features
# `strings_x` is the input character-based strings features
# `strings_y` is the output character-based strings features

all_feat_x = [
    "MXpos", "STpos", "AMpos", "FApos", "STaspect", "AMaspect", "MXaspect",
    "FAaspect", "STperson", "AMperson", "MXperson", "FAperson", "STgender",
    "AMgender", "MXgender", "FAgender", "STnumber", "AMnumber", "MXnumber",
    "FAnumber", "STcase", "AMcase", "MXcase", "FAcase", "STvoice",
    "AMvoice", "MXvoice", "FAvoice", "STmood", "AMmood", "MXmood",
    "FAmood", "STstate", "AMstate", "MXstate", "FAstate"
]
feat_y = [
    "QApos", "QAaspect", "QAperson", "QAgender", "QAnumber", "QAcase",
    "QAvoice", "QAmood", "QAstate"
]
strings_x = ["QAwutf8"]
strings_y = ["QAutf8"]

# %%
def pretty_join(arr):
    if isinstance(arr, pd.Series):
        arr = arr.to_frame().T
    if isinstance(arr.columns, pd.core.index.MultiIndex):
        return "/".join([
            '+'.join([
                x[1] for x in arr.columns[row == 1]
                if x[1][-2:] != "na" and x[1][-2:] != "_0"
            ]) for index, row in arr.iterrows()
        ])
    else:
        return "/".join([
            '+'.join([
                x for x in arr.columns[row == 1]
                if x[-2:] != "na" and x[-2:] != "_0"
            ]) for index, row in arr.iterrows()
        ])


def pretty_value(colum_value):
    return re.sub(".*_", "", colum_value)


def getValuesAndReshape(df, middle_dim):
    return df.values.reshape((df.shape[0] // middle_dim, middle_dim, -1))


def flattencolumns(df1, cols):
    df = pd.concat(
        [pd.DataFrame(df1[x].values.tolist()).add_prefix(x) for x in cols],
        axis=1)
    return pd.concat([df, df1.drop(cols, axis=1)], axis=1)


def truncate(x):
    return x[:EMBEDDINGS]


def removeDiac(x):
    return re.sub('[ًٌٍَُِّْ]', '', x.replace("ٱ", "ا"))


def padStringWithSpaces(x):
    return x + ' ' * (STRING_LENGTH - len(x))


def joinMorphemesStrings(arr):
    return "+".join([
        x for x in arr if (isinstance(x, float) is False and
                           len(x) != 0 and x != "-----" and x != "-")
    ])


def emb_encode(x):
    return np.zeros(emb.vector_size) if x.strip() == "" else emb[x]


def fullprint(*args, **kwargs):
    opt = np.get_printoptions()
    np.set_printoptions(threshold='nan')
    pprint(*args, **kwargs)
    np.set_printoptions(**opt)


def getMorphemeBasedIndeicies(arr):
    return np.array([list(range(x * 5, x * 5 + 5)) for x in arr]).flatten()


def getData(cat_source,
            str_source,
            cats_feats=[],
            strs_feats=[],
            embeddings=False):
    data = {
        **{
            i: getValuesAndReshape(
                cat_source[i].idxmax(axis=1).apply(
                    lambda x: embeddingInputLists[i].index(x)),
                SENTLEN)
            # getValuesAndReshape(cat_source.loc[:, ("vals", i)], SENTLEN)
            if (i in embeddingInputSets and
                len(embeddingInputSets[i]) > CATS_EMBEDDING)
            else getValuesAndReshape(cat_source[i], SENTLEN)
            for i in cats_feats
        },
        **{
            i: np.stack(str_source[i + "_onehot"].values)
            for i in strs_feats
        },
        # "embeddings": getValuesAndReshape(cat_source[i], SENTLEN),
    }
    if embeddings:
        for i in strs_feats:
            data[i + "_emb"] = np.stack(str_source[i + "_emb"].values)
    return data


def getSet(df):
    results = set()
    df.apply(results.add)
    return results


def getEmbedding(input, feat_x):
    name = input.name.split("_")[0]
    if name in feat_x and len(embeddingInputSets[name]) > CATS_EMBEDDING:
        return layers.Reshape((SENTLEN, -1))(
            layers.Embedding(len(embeddingInputSets[name]), 2,
                             input_length=SENTLEN)(input))
    else:
        return layers.Dropout(0.1)(input)

# %%
# # 4. Loading data from sawaref


sawarefData = SawarefData(
    MYPATH,
    EMBEDDINGS,
    feat_x=all_feat_x,
    strings_x=strings_x,
    strings_y=strings_y,
    feat_y=feat_y)

source = list(itertools.chain(*sawarefData.quran_sent))
df = pd.DataFrame(
    source,
    columns=["sid", "aid", "wid", "mid"] + all_feat_x + strings_x + strings_y +
    ["embeddings"] + feat_y)
df["embeddings"] = df["embeddings"].apply(truncate)
df = flattencolumns(df, ["embeddings"])
df.set_index(["sid", "aid", "wid", "mid"], inplace=True)
df.sort_index(inplace=True)

# 2. Pad the rows according to the longest word (in # of morphemes)
SENTLEN = max(df.index.get_level_values("mid"))
df = df.reindex(
    padIndexes(df, max(df.index.get_level_values("mid"))),
    fill_value=0).sort_index()

# 3. Get the hot encoding of all caterogirical data (see columns attr)
dumm = pd.get_dummies(df, columns=all_feat_x + feat_y)

# 4. Add two-level columns for easy indexing later (wid, mid)
EXAMPLES_LEN = df.shape[0] // SENTLEN
new_columns = []
for x in dumm.columns:
    new_columns.append(re.sub('(_.*|[0-9]*)', '', x))
dumm.columns = [new_columns, dumm.columns]
dumm.index = [[x for x in range(EXAMPLES_LEN) for _ in range(SENTLEN)],
              [x for _ in range(EXAMPLES_LEN) for x in range(SENTLEN)]]
dumm.sort_index(axis=1, inplace=True)

# 5. Find possible values of each cat
embeddingInputSets = {i: getSet(df[i]) for i in all_feat_x}
embeddingInputLists = {
    i: [i + "_" + str(x) for x in embeddingInputSets[i]]
    for i in embeddingInputSets
}


# embeddingInputSets

all_feat_x = list(
    set(all_feat_x) -
    set([x for x in all_feat_x if len(embeddingInputSets[x]) <= 1]))

df2 = pd.concat([df.reset_index(), dumm.reset_index()], axis=1)
# df2.set_index(["sid", "aid", "wid", "mid"], inplace=True)
df2.index = [[x for x in range(EXAMPLES_LEN) for _ in range(SENTLEN)],
             [x for _ in range(EXAMPLES_LEN) for x in range(SENTLEN)]]

df2.drop(['embeddings' + str(x) for x in range(100)], inplace=True, axis=1)
# df2.columns = [(x,"val") if isinstance(x,str)
# else x  for x in df2.columns]

df2.index = [[x for x in range(EXAMPLES_LEN) for _ in range(SENTLEN)],
             [x for _ in range(EXAMPLES_LEN) for x in range(SENTLEN)]]

df2.columns = [[
    "vals" if isinstance(x, str) else x[0] for x in df2.columns
], [x if isinstance(x, str) else x[1] for x in df2.columns]]

df2.sort_index(axis=1, inplace=True)

del df
del dumm

# 5. Prepare string columns:
# a. clean all padded rows
strings = strings_x + strings_y
for s in strings:
    #         print(df2[s])
    df2.loc[df2[("vals", s)] == 0, ("vals", s)] = ""
    df2.loc[pd.isna(df2[("vals", s)]), ("vals", s)] = ""
for x in strings:
    df2[(x, "undiac")] = df2[("vals", x)].apply(removeDiac)

df2["vals", "QAutf8"].groupby(level=[0]).apply(joinMorphemesStrings).head()

# b. group them by morpheme and join with "+""
df_strings = pd.DataFrame({
    x: df2["vals", x].groupby(level=[0]).apply(joinMorphemesStrings)
    for x in strings
})

# df_strings

# c. pad joined morphemes
STRING_LENGTH = max([len(x) for k in strings for x in df_strings[k]])
for s in strings:
    df_strings[s] = df_strings[s].apply(padStringWithSpaces)

# d. encode them in one hot encoding
charset = set("+").union(
    *[list(set("".join(df_strings[x] + "-"))) for x in strings])
ctable = CharacterTable(charset, STRING_LENGTH)
# Now we have one shape for all strings: (STRING_LENGTH, len(charset))
for x in strings:
    df_strings[x + "_onehot"] = df_strings[x].apply(ctable.encode)
df_strings['num'] = [x for x in range(len(df_strings))]
df_strings.set_index('num', append=True, inplace=True)

if WORD_EMB:
    # e. remove diac
    for x in strings:
        df_strings[x + "_undiac"] = df_strings[x].apply(removeDiac)

    # f. encode them as dense vector using fastText
    for x in strings:
        df_strings[x + "_emb"] = df_strings[x + "_undiac"].apply(emb_encode)
# Out:
# 1111
# Vectorization...

# %%
print("START FOR LOOP ")
tools = ["MX", "FA", "AM", "ST"]

subset = ("MX", "FA", "AM", "ST")
feat_x = [s for s in all_feat_x if s.startswith(subset)]

np.random.seed(0)
subset_name = ",".join(subset)
print("subset=", subset_name, flush=True)
# print("feat_x=", feat_x)
thedate = (str(subset_name) +
           "+" + datetime.datetime.now().strftime(".%Y.%m.%d.%H.%M"))

# # 6. Prepare splits

# 6. Shuffle (x, y) in unison
indices = list(range(EXAMPLES_LEN))
np.random.shuffle(indices)

# indices
# 7. Explicitly set apart 10% for validation data that we never train over.
test_split_at = int(EXAMPLES_LEN * TEST_SPLIT / 10)
val_split_at = int(EXAMPLES_LEN * TEST_SPLIT / 10 +
                   EXAMPLES_LEN * VAL_SPLIT / 10)

# print(EXAMPLES_LEN, val_split_at, test_split_at)

values_test = df_strings.iloc[indices[:test_split_at]]
values_val = df_strings.iloc[indices[test_split_at:val_split_at]]
values_train = df_strings.iloc[indices[val_split_at:]]

test = df2.iloc[getMorphemeBasedIndeicies(indices[:test_split_at])]
val = df2.iloc[getMorphemeBasedIndeicies(
    indices[test_split_at:val_split_at])]
train = df2.iloc[getMorphemeBasedIndeicies(indices[val_split_at:])]


print(EXAMPLES_LEN, TEST_SPLIT / 10, VAL_SPLIT / 10,
      test_split_at, val_split_at)
print(values_test.shape, values_val.shape, values_train.shape)
print(test.shape, val.shape, train.shape)
print(test.shape[0] // 5)
# Out:
# START FOR LOOP
# subset= MX,FA,AM,ST
# 22570 0.8 0.1 18056 20313
# (18056, 4) (2257, 4) (2257, 4)
# (90280, 438) (11285, 438) (11285, 438)
# 18056

# %%
def getData(cat_source,
            str_source,
            cats_feats=[],
            strs_feats=[],
            embeddings=False, aggregated=False):
    data = {
        **{
            i: getValuesAndReshape(
                cat_source[i].idxmax(axis=1).apply(
                    lambda x: embeddingInputLists[i].index(x)),
                SENTLEN)
            # getValuesAndReshape(cat_source.loc[:, ("vals", i)], SENTLEN)
            if (i in embeddingInputSets and
                len(embeddingInputSets[i]) > CATS_EMBEDDING)
            else getValuesAndReshape(cat_source[i], SENTLEN)
            for i in cats_feats
        },
        **{
            i: np.stack(str_source[i + "_onehot"].values)
            for i in strs_feats
        },
        # "embeddings": getValuesAndReshape(cat_source[i], SENTLEN),
    }
    if embeddings:
        for i in strs_feats:
            data[i + "_emb"] = np.stack(str_source[i + "_emb"].values)
    if aggregated:
        data["aggregated"] = np.concatenate([np.reshape(data[x],(data[x].shape[0],-1)) for x in data], axis=1)
    return data


data = {
    'input':
    getData(train, values_train, cats_feats=feat_x, strs_feats=strings_x,
            embeddings=WORD_EMB),
    'output':
    getData(train, values_train, cats_feats=feat_y,
            strs_feats=strings_y, aggregated=True),
    'val':
    (getData(val, values_val, cats_feats=feat_x, strs_feats=strings_x,
             embeddings=WORD_EMB),
     getData(val, values_val, cats_feats=feat_y, strs_feats=strings_y, aggregated=True)),
    'test': (
        getData(test, values_test, cats_feats=feat_x, strs_feats=strings_x,
                embeddings=WORD_EMB),
        getData(
            test,
            values_test,
            cats_feats=feat_y,
            strs_feats=strings_y,
            aggregated=True
        ))
}

# 8. Some info about shapes
print('\nTraining Data:')
print("\n".join(["X: " + i + str(data["input"][i].shape)
                 for i in data["input"]]))
print("\n".join(
    ["Y: " + i + str(data["output"][i].shape) for i in data["output"]]))
print('\nValidation Data:')
print("\n".join(
    ["X: " + i + str(data["val"][0][i].shape) for i in data["val"][0]]))
print("\n".join(
    ["Y: " + i + str(data["val"][1][i].shape) for i in data["val"][1]]))
print('\nTest Data:')
print("\n".join(
    ["X: " + i + str(data["test"][0][i].shape) for i in data["test"][0]]))
print("\n".join(
    ["Y: " + i + str(data["test"][1][i].shape) for i in data["test"][1]]))
# Out:
# Training Data:
# X: AMpos(2257, 5, 1)
# X: MXpos(2257, 5, 1)
# X: FApos(2257, 5, 1)
# X: AMvoice(2257, 5, 3)
# X: MXcase(2257, 5, 5)
# X: MXperson(2257, 5, 5)
# X: FAperson(2257, 5, 2)
# X: MXmood(2257, 5, 4)
# X: MXgender(2257, 5, 4)
# X: MXstate(2257, 5, 4)
# X: AMperson(2257, 5, 3)
# X: STaspect(2257, 5, 4)
# X: MXaspect(2257, 5, 5)
# X: MXvoice(2257, 5, 4)
# X: AMaspect(2257, 5, 4)
# X: STvoice(2257, 5, 3)
# X: MXnumber(2257, 5, 5)
# X: STpos(2257, 5, 1)
# X: QAwutf8(2257, 25, 75)
# X: STnumber(2257, 5, 3)
# Y: QAmood(2257, 5, 6)
# Y: QAperson(2257, 5, 5)
# Y: QAvoice(2257, 5, 4)
# Y: QAnumber(2257, 5, 6)
# Y: QAcase(2257, 5, 5)
# Y: QAgender(2257, 5, 4)
# Y: aggregated(2257, 2320)
# Y: QAaspect(2257, 5, 4)
# Y: QAstate(2257, 5, 5)
# Y: QAutf8(2257, 25, 75)
# Y: QApos(2257, 5, 50)
#
# Validation Data:
# X: AMpos(2257, 5, 1)
# X: MXpos(2257, 5, 1)
# X: FApos(2257, 5, 1)
# X: AMvoice(2257, 5, 3)
# X: MXcase(2257, 5, 5)
# X: MXperson(2257, 5, 5)
# X: FAperson(2257, 5, 2)
# X: MXmood(2257, 5, 4)
# X: MXgender(2257, 5, 4)
# X: MXstate(2257, 5, 4)
# X: AMperson(2257, 5, 3)
# X: STaspect(2257, 5, 4)
# X: MXaspect(2257, 5, 5)
# X: MXvoice(2257, 5, 4)
# X: AMaspect(2257, 5, 4)
# X: STvoice(2257, 5, 3)
# X: MXnumber(2257, 5, 5)
# X: STpos(2257, 5, 1)
# X: QAwutf8(2257, 25, 75)
# X: STnumber(2257, 5, 3)
# Y: QAmood(2257, 5, 6)
# Y: QAperson(2257, 5, 5)
# Y: QAvoice(2257, 5, 4)
# Y: QAnumber(2257, 5, 6)
# Y: QAcase(2257, 5, 5)
# Y: QAgender(2257, 5, 4)
# Y: aggregated(2257, 2320)
# Y: QAaspect(2257, 5, 4)
# Y: QAstate(2257, 5, 5)
# Y: QAutf8(2257, 25, 75)
# Y: QApos(2257, 5, 50)
#
# Test Data:
# X: AMpos(18056, 5, 1)
# X: MXpos(18056, 5, 1)
# X: FApos(18056, 5, 1)
# X: AMvoice(18056, 5, 3)
# X: MXcase(18056, 5, 5)
# X: MXperson(18056, 5, 5)
# X: FAperson(18056, 5, 2)
# X: MXmood(18056, 5, 4)
# X: MXgender(18056, 5, 4)
# X: MXstate(18056, 5, 4)
# X: AMperson(18056, 5, 3)
# X: STaspect(18056, 5, 4)
# X: MXaspect(18056, 5, 5)
# X: MXvoice(18056, 5, 4)
# X: AMaspect(18056, 5, 4)
# X: STvoice(18056, 5, 3)
# X: MXnumber(18056, 5, 5)
# X: STpos(18056, 5, 1)
# X: QAwutf8(18056, 25, 75)
# X: STnumber(18056, 5, 3)
# Y: QAmood(18056, 5, 6)
# Y: QAperson(18056, 5, 5)
# Y: QAvoice(18056, 5, 4)
# Y: QAnumber(18056, 5, 6)
# Y: QAcase(18056, 5, 5)
# Y: QAgender(18056, 5, 4)
# Y: aggregated(18056, 2320)
# Y: QAaspect(18056, 5, 4)
# Y: QAstate(18056, 5, 5)
# Y: QAutf8(18056, 25, 75)
# Y: QApos(18056, 5, 50)

# %%
# # 7. Load Previous model

# model = load_model(MODEL_NAME)

# # 8. Build Model

print('Build model...')
outputs = []
inputs = []
# For strings
strings_input = layers.Input(
    shape=(STRING_LENGTH, len(charset)), name=strings_x[0])
lstm_strings_encoder = layers.Bidirectional(
    RNN(HIDDEN_SIZE, name="lstm_strings_encoder"))(strings_input)

# For categoricals
for i in feat_x:
    inputs.append(
        layers.Input(shape=(SENTLEN, data["input"][i].shape[2]), name=i))

# main_input = layers.Concatenate()(
#                     [layers.Dropout(0.1)(input) for input in inputs])

concatenatedInputs = [lstm_strings_encoder]
if len(inputs) >= 1:
    main_input = layers.Concatenate()(
        [getEmbedding(input, feat_x) for input in inputs])

    lstm_out = layers.Bidirectional(RNN(HIDDEN_SIZE))(main_input)
    concatenatedInputs.append(lstm_out)
# input_shape=(None, len(ctable_x.chars) + EMBEDDINGS)))
# As the decoder RNN's input, repeatedly provide with last hidden state of
# RNN for each time step. Repeat 'DIGITS + 1' times as that's the maximum
# length of output, e.g., when DIGITS=3, max output is 999+999=1998.
inputs.append(strings_input)
if WORD_EMB:
    emb_input = layers.Input(shape=(emb.vector_size,),
                             name=strings_x[0] + "_emb")
    inputs.append(emb_input)
    concatenatedInputs.append(emb_input)

if len(concatenatedInputs) > 1:
    concatenated = layers.Concatenate()(concatenatedInputs)
else:
    concatenated = concatenatedInputs[0]

# For strings again
repeat_strings_out = layers.RepeatVector(STRING_LENGTH)(concatenated)
rnn_out = RNN(HIDDEN_SIZE, return_sequences=True)(repeat_strings_out)
strings_output = layers.TimeDistributed(
    layers.Dense(len(charset), activation="softmax"),
    name=strings_y[0])(rnn_out)
outputs.append(strings_output)

dropout_out = layers.Dropout(0.5)(concatenated)
repeat_out = layers.RepeatVector(SENTLEN)(dropout_out)
# The decoder RNN could be multiple layers stacked or a single layer.
rnn_out = RNN(HIDDEN_SIZE, return_sequences=True)(repeat_out)
# By setting return_sequences to True, return not only the last output but
# all the outputs so far in the form of (num_samples, timesteps,
# output_dim). This is necessary as TimeDistributed in the below expects
# the first dimension to be the timesteps.
for _ in range(LAYERS - 1):
    rnn_out = RNN(HIDDEN_SIZE, return_sequences=True)(rnn_out)

# Apply a dense layer to the every temporal slice of an input. For each of
# step of the output sequence, decide which character should be chosen.

for i in feat_y:
    outputs.append(
        layers.TimeDistributed(
            layers.Dense(data["output"][i].shape[2], activation="softmax"),
            name=i)(rnn_out))

agg = layers.Concatenate(name="aggregated")([layers.Flatten()(output) for output in outputs])
model = Model(inputs=inputs, outputs=outputs+[agg])

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy'])
# Out:
# Build model...

# %%
# print(inputs,outputs)
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

# # 9. Summary

model.summary()

# from IPython.display import SVG
# from keras.utils.vis_utils import model_to_dot
# plot_model(
#     model, to_file='plots/model.{}.png'.format(thedate), show_shapes=True)
SVG(model_to_dot(model, show_shapes=True, show_layer_names=True
   ).create(prog='dot', format='svg'))

# # 10. Training
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# MXpos (InputLayer)              (None, 5, 1)         0
# __________________________________________________________________________________________________
# FApos (InputLayer)              (None, 5, 1)         0
# __________________________________________________________________________________________________
# MXstate (InputLayer)            (None, 5, 4)         0
# __________________________________________________________________________________________________
# embedding_9 (Embedding)         (None, 5, 2)         82          MXpos[0][0]
# __________________________________________________________________________________________________
# MXaspect (InputLayer)           (None, 5, 5)         0
# __________________________________________________________________________________________________
# MXnumber (InputLayer)           (None, 5, 5)         0
# __________________________________________________________________________________________________
# embedding_10 (Embedding)        (None, 5, 2)         34          FApos[0][0]
# __________________________________________________________________________________________________
# MXvoice (InputLayer)            (None, 5, 4)         0
# __________________________________________________________________________________________________
# MXcase (InputLayer)             (None, 5, 5)         0
# __________________________________________________________________________________________________
# MXperson (InputLayer)           (None, 5, 5)         0
# __________________________________________________________________________________________________
# FAperson (InputLayer)           (None, 5, 2)         0
# __________________________________________________________________________________________________
# MXgender (InputLayer)           (None, 5, 4)         0
# __________________________________________________________________________________________________
# MXmood (InputLayer)             (None, 5, 4)         0
# __________________________________________________________________________________________________
# dropout_53 (Dropout)            (None, 5, 4)         0           MXstate[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 5, 2)         0           embedding_9[0][0]
# __________________________________________________________________________________________________
# dropout_54 (Dropout)            (None, 5, 5)         0           MXaspect[0][0]
# __________________________________________________________________________________________________
# dropout_55 (Dropout)            (None, 5, 5)         0           MXnumber[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 5, 2)         0           embedding_10[0][0]
# __________________________________________________________________________________________________
# dropout_56 (Dropout)            (None, 5, 4)         0           MXvoice[0][0]
# __________________________________________________________________________________________________
# dropout_57 (Dropout)            (None, 5, 5)         0           MXcase[0][0]
# __________________________________________________________________________________________________
# dropout_58 (Dropout)            (None, 5, 5)         0           MXperson[0][0]
# __________________________________________________________________________________________________
# dropout_59 (Dropout)            (None, 5, 2)         0           FAperson[0][0]
# __________________________________________________________________________________________________
# dropout_60 (Dropout)            (None, 5, 4)         0           MXgender[0][0]
# __________________________________________________________________________________________________
# dropout_61 (Dropout)            (None, 5, 4)         0           MXmood[0][0]
# __________________________________________________________________________________________________
# QAwutf8 (InputLayer)            (None, 25, 75)       0
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 5, 42)        0           dropout_53[0][0]
#                                                                  reshape_9[0][0]
#                                                                  dropout_54[0][0]
#                                                                  dropout_55[0][0]
#                                                                  reshape_10[0][0]
#                                                                  dropout_56[0][0]
#                                                                  dropout_57[0][0]
#                                                                  dropout_58[0][0]
#                                                                  dropout_59[0][0]
#                                                                  dropout_60[0][0]
#                                                                  dropout_61[0][0]
# __________________________________________________________________________________________________
# bidirectional_11 (Bidirectional (None, 256)          208896      QAwutf8[0][0]
# __________________________________________________________________________________________________
# bidirectional_12 (Bidirectional (None, 256)          175104      concatenate_14[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 512)          0           bidirectional_11[0][0]
#                                                                  bidirectional_12[0][0]
# __________________________________________________________________________________________________
# dropout_62 (Dropout)            (None, 512)          0           concatenate_15[0][0]
# __________________________________________________________________________________________________
# repeat_vector_11 (RepeatVector) (None, 25, 512)      0           concatenate_15[0][0]
# __________________________________________________________________________________________________
# repeat_vector_12 (RepeatVector) (None, 5, 512)       0           dropout_62[0][0]
# __________________________________________________________________________________________________
# lstm_17 (LSTM)                  (None, 25, 128)      328192      repeat_vector_11[0][0]
# __________________________________________________________________________________________________
# lstm_18 (LSTM)                  (None, 5, 128)       328192      repeat_vector_12[0][0]
# __________________________________________________________________________________________________
# QAutf8 (TimeDistributed)        (None, 25, 75)       9675        lstm_17[0][0]
# __________________________________________________________________________________________________
# QApos (TimeDistributed)         (None, 5, 50)        6450        lstm_18[0][0]
# __________________________________________________________________________________________________
# QAaspect (TimeDistributed)      (None, 5, 4)         516         lstm_18[0][0]
# __________________________________________________________________________________________________
# QAperson (TimeDistributed)      (None, 5, 5)         645         lstm_18[0][0]
# __________________________________________________________________________________________________
# QAgender (TimeDistributed)      (None, 5, 4)         516         lstm_18[0][0]
# __________________________________________________________________________________________________
# QAnumber (TimeDistributed)      (None, 5, 6)         774         lstm_18[0][0]
# __________________________________________________________________________________________________
# QAcase (TimeDistributed)        (None, 5, 5)         645         lstm_18[0][0]
# __________________________________________________________________________________________________
# QAvoice (TimeDistributed)       (None, 5, 4)         516         lstm_18[0][0]
# __________________________________________________________________________________________________
# QAmood (TimeDistributed)        (None, 5, 6)         774         lstm_18[0][0]
# __________________________________________________________________________________________________
# QAstate (TimeDistributed)       (None, 5, 5)         645         lstm_18[0][0]
# __________________________________________________________________________________________________
# flatten_22 (Flatten)            (None, 1875)         0           QAutf8[0][0]
# __________________________________________________________________________________________________
# flatten_23 (Flatten)            (None, 250)          0           QApos[0][0]
# __________________________________________________________________________________________________
# flatten_24 (Flatten)            (None, 20)           0           QAaspect[0][0]
# __________________________________________________________________________________________________
# flatten_25 (Flatten)            (None, 25)           0           QAperson[0][0]
# __________________________________________________________________________________________________
# flatten_26 (Flatten)            (None, 20)           0           QAgender[0][0]
# __________________________________________________________________________________________________
# flatten_27 (Flatten)            (None, 30)           0           QAnumber[0][0]
# __________________________________________________________________________________________________
# flatten_28 (Flatten)            (None, 25)           0           QAcase[0][0]
# __________________________________________________________________________________________________
# flatten_29 (Flatten)            (None, 20)           0           QAvoice[0][0]
# __________________________________________________________________________________________________
# flatten_30 (Flatten)            (None, 30)           0           QAmood[0][0]
# __________________________________________________________________________________________________
# flatten_31 (Flatten)            (None, 25)           0           QAstate[0][0]
# __________________________________________________________________________________________________
# aggregated (Concatenate)        (None, 2320)         0           flatten_22[0][0]
#                                                                  flatten_23[0][0]
#                                                                  flatten_24[0][0]
#                                                                  flatten_25[0][0]
#                                                                  flatten_26[0][0]
#                                                                  flatten_27[0][0]
#                                                                  flatten_28[0][0]
#                                                                  flatten_29[0][0]
#                                                                  flatten_30[0][0]
#                                                                  flatten_31[0][0]
# ==================================================================================================
# Total params: 1,061,656
# Trainable params: 1,061,656
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
earlyStopping = EarlyStopping(
    monitor='val_loss', patience=5, verbose=0, mode='auto')

tensorboard = TensorBoard(
    log_dir="logs/" + NAME + "_{}".format(thedate), write_graph=False)

# %%
# continue
history = model.fit(
    data['input'],
    data['output'],
    batch_size=BATCH_SIZE,
    callbacks=[earlyStopping,
               TestCallback(data['test']), tensorboard],
    epochs=EPOCHS,
    verbose=2,
    validation_data=data['val'])
# Out:
# Train on 2257 samples, validate on 2257 samples
# Epoch 1/100
#  - 8s - loss: 523.9986 - QAutf8_loss: 4.6108 - QApos_loss: 2.9534 - QAaspect_loss: 0.5022 - QAperson_loss: 0.6704 - QAgender_loss: 0.7193 - QAnumber_loss: 0.7640 - QAcase_loss: 0.6444 - QAvoice_loss: 0.4336 - QAmood_loss: 0.6904 - QAstate_loss: 0.6293 - aggregated_loss: 511.3809 - QAutf8_acc: 0.0037 - QApos_acc: 0.0231 - QAaspect_acc: 0.8724 - QAperson_acc: 0.8382 - QAgender_acc: 0.8214 - QAnumber_acc: 0.8465 - QAcase_acc: 0.8761 - QAvoice_acc: 0.9390 - QAmood_acc: 0.8684 - QAstate_acc: 0.8629 - aggregated_acc: 0.0000e+00 - val_loss: 486.1817 - val_QAutf8_loss: 4.8233 - val_QApos_loss: 2.7555 - val_QAaspect_loss: 0.2112 - val_QAperson_loss: 0.4746 - val_QAgender_loss: 0.5094 - val_QAnumber_loss: 0.5542 - val_QAcase_loss: 0.4764 - val_QAvoice_loss: 0.1934 - val_QAmood_loss: 0.5532 - val_QAstate_loss: 0.2670 - val_aggregated_loss: 475.3634 - val_QAutf8_acc: 0.0017 - val_QApos_acc: 0.2063 - val_QAaspect_acc: 0.9510 - val_QAperson_acc: 0.9019 - val_QAgender_acc: 0.8385 - val_QAnumber_acc: 0.8616 - val_QAcase_acc: 0.9149 - val_QAvoice_acc: 0.9482 - val_QAmood_acc: 0.7967 - val_QAstate_acc: 0.9437 - val_aggregated_acc: 0.0000e+00
# Epoch 2/100
#  - 8s - loss: 477.5553 - QAutf8_loss: 4.5853 - QApos_loss: 2.6446 - QAaspect_loss: 0.2088 - QAperson_loss: 0.4676 - QAgender_loss: 0.4743 - QAnumber_loss: 0.5036 - QAcase_loss: 0.3926 - QAvoice_loss: 0.1745 - QAmood_loss: 0.4985 - QAstate_loss: 0.2447 - aggregated_loss: 467.3608 - QAutf8_acc: 0.0031 - QApos_acc: 0.1890 - QAaspect_acc: 0.9500 - QAperson_acc: 0.8886 - QAgender_acc: 0.8352 - QAnumber_acc: 0.8578 - QAcase_acc: 0.9166 - QAvoice_acc: 0.9494 - QAmood_acc: 0.7994 - QAstate_acc: 0.9435 - aggregated_acc: 0.0000e+00 - val_loss: 469.9643 - val_QAutf8_loss: 4.3545 - val_QApos_loss: 2.5449 - val_QAaspect_loss: 0.2081 - val_QAperson_loss: 0.4412 - val_QAgender_loss: 0.4605 - val_QAnumber_loss: 0.4509 - val_QAcase_loss: 0.3739 - val_QAvoice_loss: 0.1755 - val_QAmood_loss: 0.5041 - val_QAstate_loss: 0.2400 - val_aggregated_loss: 460.2109 - val_QAutf8_acc: 0.0035 - val_QApos_acc: 0.1387 - val_QAaspect_acc: 0.9510 - val_QAperson_acc: 0.8852 - val_QAgender_acc: 0.8385 - val_QAnumber_acc: 0.8616 - val_QAcase_acc: 0.9149 - val_QAvoice_acc: 0.9482 - val_QAmood_acc: 0.7967 - val_QAstate_acc: 0.9437 - val_aggregated_acc: 0.0000e+00
# Epoch 3/100
#  - 9s - loss: 466.0740 - QAutf8_loss: 4.3561 - QApos_loss: 2.3845 - QAaspect_loss: 0.1995 - QAperson_loss: 0.4400 - QAgender_loss: 0.4484 - QAnumber_loss: 0.4377 - QAcase_loss: 0.3650 - QAvoice_loss: 0.1625 - QAmood_loss: 0.4736 - QAstate_loss: 0.2341 - aggregated_loss: 456.5726 - QAutf8_acc: 0.0037 - QApos_acc: 0.1902 - QAaspect_acc: 0.9500 - QAperson_acc: 0.8720 - QAgender_acc: 0.8433 - QAnumber_acc: 0.8571 - QAcase_acc: 0.9166 - QAvoice_acc: 0.9494 - QAmood_acc: 0.7994 - QAstate_acc: 0.9435 - aggregated_acc: 0.0000e+00 - val_loss: 462.7138 - val_QAutf8_loss: 4.3286 - val_QApos_loss: 2.3055 - val_QAaspect_loss: 0.2024 - val_QAperson_loss: 0.4178 - val_QAgender_loss: 0.4280 - val_QAnumber_loss: 0.4027 - val_QAcase_loss: 0.3694 - val_QAvoice_loss: 0.1618 - val_QAmood_loss: 0.4751 - val_QAstate_loss: 0.2287 - val_aggregated_loss: 453.3937 - val_QAutf8_acc: 0.0036 - val_QApos_acc: 0.2572 - val_QAaspect_acc: 0.9510 - val_QAperson_acc: 0.8767 - val_QAgender_acc: 0.8531 - val_QAnumber_acc: 0.8642 - val_QAcase_acc: 0.9149 - val_QAvoice_acc: 0.9482 - val_QAmood_acc: 0.7967 - val_QAstate_acc: 0.9437 - val_aggregated_acc: 0.0000e+00
# Epoch 4/100
#  - 9s - loss: 460.8354 - QAutf8_loss: 4.3090 - QApos_loss: 2.2010 - QAaspect_loss: 0.1958 - QAperson_loss: 0.4219 - QAgender_loss: 0.4233 - QAnumber_loss: 0.4038 - QAcase_loss: 0.3591 - QAvoice_loss: 0.1532 - QAmood_loss: 0.4647 - QAstate_loss: 0.2252 - aggregated_loss: 451.6784 - QAutf8_acc: 0.0038 - QApos_acc: 0.3113 - QAaspect_acc: 0.9500 - QAperson_acc: 0.8693 - QAgender_acc: 0.8536 - QAnumber_acc: 0.8590 - QAcase_acc: 0.9166 - QAvoice_acc: 0.9494 - QAmood_acc: 0.7994 - QAstate_acc: 0.9435 - aggregated_acc: 0.0000e+00 - val_loss: 459.1936 - val_QAutf8_loss: 4.3151 - val_QApos_loss: 2.2014 - val_QAaspect_loss: 0.1850 - val_QAperson_loss: 0.3920 - val_QAgender_loss: 0.4295 - val_QAnumber_loss: 0.3775 - val_QAcase_loss: 0.3600 - val_QAvoice_loss: 0.1528 - val_QAmood_loss: 0.4604 - val_QAstate_loss: 0.2212 - val_aggregated_loss: 450.0987 - val_QAutf8_acc: 0.0046 - val_QApos_acc: 0.3308 - val_QAaspect_acc: 0.9510 - val_QAperson_acc: 0.8753 - val_QAgender_acc: 0.8538 - val_QAnumber_acc: 0.8681 - val_QAcase_acc: 0.9149 - val_QAvoice_acc: 0.9482 - val_QAmood_acc: 0.7967 - val_QAstate_acc: 0.9437 - val_aggregated_acc: 0.0000e+00
# Epoch 5/100
#  - 9s - loss: 457.4806 - QAutf8_loss: 4.3192 - QApos_loss: 2.1124 - QAaspect_loss: 0.1864 - QAperson_loss: 0.4130 - QAgender_loss: 0.4154 - QAnumber_loss: 0.3875 - QAcase_loss: 0.3526 - QAvoice_loss: 0.1477 - QAmood_loss: 0.4587 - QAstate_loss: 0.2187 - aggregated_loss: 448.4691 - QAutf8_acc: 0.0057 - QApos_acc: 0.3495 - QAaspect_acc: 0.9500 - QAperson_acc: 0.8636 - QAgender_acc: 0.8561 - QAnumber_acc: 0.8588 - QAcase_acc: 0.9166 - QAvoice_acc: 0.9494 - QAmood_acc: 0.7994 - QAstate_acc: 0.9435 - aggregated_acc: 0.0000e+00 - val_loss: 456.0618 - val_QAutf8_loss: 4.2819 - val_QApos_loss: 2.1069 - val_QAaspect_loss: 0.1757 - val_QAperson_loss: 0.3848 - val_QAgender_loss: 0.3939 - val_QAnumber_loss: 0.3678 - val_QAcase_loss: 0.3467 - val_QAvoice_loss: 0.1435 - val_QAmood_loss: 0.4670 - val_QAstate_loss: 0.2154 - val_aggregated_loss: 447.1782 - val_QAutf8_acc: 0.0064 - val_QApos_acc: 0.3304 - val_QAaspect_acc: 0.9510 - val_QAperson_acc: 0.8677 - val_QAgender_acc: 0.8614 - val_QAnumber_acc: 0.8661 - val_QAcase_acc: 0.9149 - val_QAvoice_acc: 0.9482 - val_QAmood_acc: 0.7967 - val_QAstate_acc: 0.9437 - val_aggregated_acc: 0.0000e+00
# Epoch 6/100
#  - 9s - loss: 455.0133 - QAutf8_loss: 4.3149 - QApos_loss: 2.0572 - QAaspect_loss: 0.1725 - QAperson_loss: 0.4009 - QAgender_loss: 0.3978 - QAnumber_loss: 0.3694 - QAcase_loss: 0.3421 - QAvoice_loss: 0.1346 - QAmood_loss: 0.4514 - QAstate_loss: 0.2109 - aggregated_loss: 446.1615 - QAutf8_acc: 0.0061 - QApos_acc: 0.3527 - QAaspect_acc: 0.9500 - QAperson_acc: 0.8575 - QAgender_acc: 0.8605 - QAnumber_acc: 0.8644 - QAcase_acc: 0.9166 - QAvoice_acc: 0.9507 - QAmood_acc: 0.7994 - QAstate_acc: 0.9435 - aggregated_acc: 0.0000e+00 - val_loss: 453.3513 - val_QAutf8_loss: 4.3645 - val_QApos_loss: 2.0730 - val_QAaspect_loss: 0.1623 - val_QAperson_loss: 0.3711 - val_QAgender_loss: 0.3878 - val_QAnumber_loss: 0.3430 - val_QAcase_loss: 0.3380 - val_QAvoice_loss: 0.1281 - val_QAmood_loss: 0.4606 - val_QAstate_loss: 0.2028 - val_aggregated_loss: 444.5200 - val_QAutf8_acc: 0.0066 - val_QApos_acc: 0.3323 - val_QAaspect_acc: 0.9510 - val_QAperson_acc: 0.8743 - val_QAgender_acc: 0.8642 - val_QAnumber_acc: 0.8832 - val_QAcase_acc: 0.9149 - val_QAvoice_acc: 0.9510 - val_QAmood_acc: 0.7967 - val_QAstate_acc: 0.9437 - val_aggregated_acc: 0.0000e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-53b8d539f73e> in <module>()
#       8     epochs=EPOCHS,
#       9     verbose=2,
# ---> 10     validation_data=data['val'])
#
# /Users/abbander/dev/py_env/tf1.4py3.5/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1710                               initial_epoch=initial_epoch,
#    1711                               steps_per_epoch=steps_per_epoch,
# -> 1712                               validation_steps=validation_steps)
#    1713
#    1714     def evaluate(self, x=None, y=None,
#
# /Users/abbander/dev/py_env/tf1.4py3.5/lib/python3.5/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1253                             for l, o in zip(out_labels, val_outs):
#    1254                                 epoch_logs['val_' + l] = o
# -> 1255             callbacks.on_epoch_end(epoch, epoch_logs)
#    1256             if callback_model.stop_training:
#    1257                 break
#
# /Users/abbander/dev/py_env/tf1.4py3.5/lib/python3.5/site-packages/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#      75         logs = logs or {}
#      76         for callback in self.callbacks:
# ---> 77             callback.on_epoch_end(epoch, logs)
#      78
#      79     def on_batch_begin(self, batch, logs=None):
#
# <ipython-input-4-aa979d42c0c3> in on_epoch_end(self, epoch, logs)
#       5     def on_epoch_end(self, epoch, logs={}):
#       6         x, y = self.test_data
# ----> 7         metrics = self.model.evaluate(x, y, verbose=0)
#       8         for i, x in enumerate(self.model.metrics_names):
#       9             logs["test_" + x] = metrics[i]
#
# /Users/abbander/dev/py_env/tf1.4py3.5/lib/python3.5/site-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps)
#    1784                                batch_size=batch_size,
#    1785                                verbose=verbose,
# -> 1786                                steps=steps)
#    1787
#    1788     def predict(self, x,
#
# /Users/abbander/dev/py_env/tf1.4py3.5/lib/python3.5/site-packages/keras/engine/training.py in _test_loop(self, f, ins, batch_size, verbose, steps)
#    1431                     ins_batch[i] = ins_batch[i].toarray()
#    1432
# -> 1433                 batch_outs = f(ins_batch)
#    1434                 if isinstance(batch_outs, list):
#    1435                     if batch_index == 0:
#
# /Users/abbander/dev/py_env/tf1.4py3.5/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2473         session = get_session()
#    2474         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2475                               **self.session_kwargs)
#    2476         return updated[:len(self.outputs)]
#    2477
#
# /Users/abbander/dev/py_env/tf1.4py3.5/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/abbander/dev/py_env/tf1.4py3.5/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /Users/abbander/dev/py_env/tf1.4py3.5/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /Users/abbander/dev/py_env/tf1.4py3.5/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /Users/abbander/dev/py_env/tf1.4py3.5/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# model.metrics_names
# model.output_names
# model.metrics
# history.history

# summarize history for loss
fig = plt.figure()
with open('history/' + thedate + '.trainHistoryDict.pickle',
          'wb') as file_pi:
    pickle.dump(history.history, file_pi)

plt.plot(history.history["loss"])
plt.plot(history.history['val_loss'])
plt.plot(history.history['test_loss'])
plt.title('model overall loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val', 'test'], loc='upper right')
filename = 'plots/model_overall_loss' + thedate + '.png'
print("PLOTTING: " + filename)
plt.draw()
plt.savefig(filename)
plt.show()
plt.close(fig)

# summarize history for loss
fig = plt.figure()
plt.plot(history.history["train_acc"])
plt.plot(history.history['val_acc'])
plt.plot(history.history['test_acc'])
plt.title('model average accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(
    [
        x + " = " +
            str(round(history.history[x + '_acc'][-1] * 100, 2))
        for x in ['train', 'val', 'test']
    ],
    loc='lower right')
# for i, x in enumerate(['train', 'val', 'test']):
#     plt.annotate(str(round(history.history[x+'_acc'][-1]*100,2)),
#                  xy=(len(history.history[x+'_acc']),
#                      history.history[x+'_acc'][-1]),
#                  textcoords='figure pixels',
#                  xytext=(-20,-10))
filename = 'plots/model_average_accuracy' + thedate + '.png'
print("PLOTTING: " + filename)
plt.draw()
plt.savefig(filename)
plt.show()
plt.close(fig)

# VALIDATAION = True
# prefix = "val_" if VALIDATAION else ""
# del prefix
fig = plt.figure()
legends = []

for x in model.output_names:
    # summarize history for accuracy
    plt.plot(history.history[x + "_acc"])
    legends.append("" + x + " = " +
                   str(round(history.history[x + '_acc'][-1] * 100, 2)))
#     plt.plot(history.history[x+"_acc"])
#     legends.append("val_"+x)
#     plt.plot(history.history["val_" + x+"_acc"])
#     legends.append("train_"+x)
plt.title('model indiviual accuracy on test dataset')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(legends, loc='lower right')
filename = 'plots/accuracy_indiv_all' + thedate + '.png'
print("PLOTTING: " + filename)
plt.draw()
plt.savefig(filename)
plt.show()
plt.close(fig)

fig = plt.figure()
legends = []
for x in model.output_names:
    # summarize history for loss
    plt.plot(history.history["test_" + x + "_loss"])
    legends.append("" + x + " = " +
                   str(round(history.history[x + '_loss'][-1] * 100, 2)))
plt.title('model individual loss on test dataset')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(legends, loc='upper right')
filename = 'plots/loss_all' + thedate + '.png'
print("PLOTTING: " + filename)
plt.draw()
plt.savefig(filename)
plt.show()
plt.close(fig)

# %%
model = load_model("models/diff_train_sizes1+.2018.06.26.20.22.keras")

# %%
mydata = data["val"]
def subset(mydata, ii=0):
    return {i:np.array([mydata[i][ii]]) for i in mydata}

eva = []
word_size = mydata[1][next(iter(mydata[1]))].shape[0]
word_level = True
for x in range(word_size):
    results = model.evaluate(subset(mydata[0],x), subset(mydata[1],x), verbose=0)
    if word_level:
        results = {metric:results[key]==1 for key, metric in enumerate(model.metrics_names) if metric.endswith("_acc")}
    else:
        results = {metric:results[key] for key, metric in enumerate(model.metrics_names) if metric.endswith("_acc")}
#     print(x, sum([results[x] for x in results]) == len(results))
    eva.append(sum([results[x] for x in results]) / len(results))
print(sum(eva)/len(eva))
# Out:
# 0.9004430660168441

# %%
eva
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  ...]

# %%
# ## 10.1 Inspect One

# ## 10.2 Inspect All

mydata = data["test"]
preds = model.predict(mydata[0])
preds = [np.argmax(x, axis=-1) for x in preds]

def pretty_join2(arr, columns, v):
    return "/".join(
        [columns[row].replace(v + "_", "") for row in arr]).rstrip("/0")

# for ite in range(len(mydata[0][strings_x[0]])):
for ite in range(100):
    print("\nPredicted String Q",
          ctable.decode(mydata[0][strings_x[0]]
                        [ite], calc_argmax=True),
          "from", "-".join(str(x) for x in values_test.index.values[ite]))

    for ii, v in enumerate(model.output_names):
        if v not in strings_y:
            continue

        if not (np.argmax(mydata[1][v][ite],
                          axis=-1) == preds[ii][ite]).all():
            print('❌' + v)
            isAllCorrect = False
            print(
                "    T",
                utf2bw(ctable.decode(mydata[1][v][ite], calc_argmax=True)))
            print("     ",
                  utf2bw(ctable.decode(preds[ii][ite], calc_argmax=False)))

    rowy = dict()
    for ii, v in enumerate(model.output_names):
        if v in strings_y:
            continue
        rowy[v] = {"correct": np.argmax(mydata[1][v][ite], axis=-1)}
        rowy[v]["pred"] = preds[ii][ite]
        results = []
        #         print(val[v].columns)
        if not (rowy[v]["correct"] == rowy[v]["pred"]).all():
            isAllCorrect = False
            print('❌' + v, end=' ')
            #             results.append('☒')
            results.append(
                'T ' + pretty_join2(rowy[v]["correct"], val[v].columns, v))
            results.append(
                pretty_join2(rowy[v]["pred"], val[v].columns, v))
            print(' '.join(results))
#         elif v =="QApos":
        else:
            results.append(
                '✅' + 'T ' +
                pretty_join2(rowy[v]["correct"], val[v].columns, v))
            results.append(
                pretty_join2(rowy[v]["pred"], val[v].columns, v))
            print(v, ' '.join(results))

# rowy

# # 11. Save Model?

# %%
model.save("models/" + NAME + "{}.keras".format(thedate))
# Out:
# START FOR LOOP
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1967677ff156> in <module>()
#       3
#       4 subset = ("MX","FA")
# ----> 5 feat_x = [s for s in all_feat_x if s.startswith(subset)]
#       6
#       7 np.random.seed(0)
#
# NameError: name 'all_feat_x' is not defined
